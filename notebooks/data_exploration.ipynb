# %%
print("Hello Cricket Project!")
print("Jupyter is working! ✅")
# Out:
# Hello Cricket Project!
# Jupyter is working! ✅

# %%
import pandas as pd
import os

# Check if data exists
if os.path.exists('../data/raw/t20/'):
    files = os.listdir('../data/raw/t20/')
    print(f"✅ Found {len(files)} files in t20 folder!")
    print(f"\nFirst 5 files:")
    for i, f in enumerate(files[:5], 1):
        print(f"{i}. {f}")
else:
    print("❌ Data folder not found! Run download_data.py first")
# Out:
# ✅ Found 9397 files in t20 folder!
#
# First 5 files:
# 1. 1001349.csv
# 2. 1001349_info.csv
# 3. 1001351.csv
# 4. 1001351_info.csv
# 5. 1001353.csv

# %%
# Show sample data
print("Sample of ball-by-ball data:")
print(df.head(10))

print("\n" + "="*50)
print("Data Info:")
df.info()

print("\n" + "="*50)
print("Unique teams:")
print(df['batting_team'].unique())
# Out:
# Sample of ball-by-ball data:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Show sample data
#       2 print("Sample of ball-by-ball data:")
# ----> 3 print(df.head(10))
#       5 print("\n" + "="*50)
#       6 print("Data Info:")
#
# NameError: name 'df' is not defined
